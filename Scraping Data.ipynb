# %%
import pandas as pd
import bs4
import requests
df_list = []
url = 'https://basketball.realgm.com/dleague/stats/2021/Advanced_Stats/Qualified/player/All/asc/%d/Regular_Season'
for i in range(1, 4):
    url_head = url %i
    df_list.append(pd.read_html(url_head)[0])
#     print(url_head)

advanced = pd.concat(df_list)
advanced
# Out:
#       #                 Player Team    TS%   eFG%  Total S %  ORB%  DRB%  \
# 0     1            Jalen Adams  ERI  0.632  0.580      178.8   2.7  14.0
# 1     2      Ty-Shon Alexander  CLE  0.606  0.546      165.8   1.5  11.8
# 2     3          Dakarai Allen  SLC  0.547  0.500      148.4   2.3   6.9
# 3     4             Sacar Anim  ACC  0.456  0.462       63.2   2.5   6.1
# 4     5         Brandon Ashley  IGN  0.628  0.581      149.2  14.0  15.1
# ..  ...                    ...  ...    ...    ...        ...   ...   ...
# 5   206         Ryan Woolridge  OKL  0.557  0.513      167.7   4.9  13.9
# 6   207           Kenny Wooten  RGV  0.589  0.521      155.8   6.9  21.2
# 7   208  Justin Wright-Foreman  ERI  0.638  0.619      152.6   1.9   7.8
# 8   209            James Young  WES  0.530  0.448      158.1   3.7  17.3
# 9   210         Omer Yurtseven  OKL  0.710  0.655      168.7  15.7  26.0
#
#     TRB%  AST%  ...  STL%  BLK%  USG%  PPR  PPS   ORtg   DRtg  eDiff    FIC  \
# ...

# %%
df_list = []
url = 'https://basketball.realgm.com/dleague/stats/2021/Averages/Qualified/player/All/asc/%d/Regular_Season'
for i in range(1, 4):
    url_head = url %i
    df_list.append(pd.read_html(url_head)[0])
#     print(url_head)

averages = pd.concat(df_list)
averages
# Out:
#       #                 Player Team  GP   MPG   PPG  FGM   FGA    FG%  3PM  \
# 0     1            Jalen Adams  ERI  14  29.1  16.1  5.8  12.1  0.479  2.4
# 1     2      Ty-Shon Alexander  CLE  15  23.7   9.3  2.9   7.3  0.404  2.1
# 2     3          Dakarai Allen  SLC   9  20.2   5.1  1.9   4.3  0.436  0.6
# 3     4             Sacar Anim  ACC  11  11.1   3.3  1.5   3.5  0.410  0.4
# 4     5         Brandon Ashley  IGN  15  20.3  10.9  4.5   8.2  0.553  0.5
# ..  ...                    ...  ...  ..   ...   ...  ...   ...    ...  ...
# 5   206         Ryan Woolridge  OKL  14  20.2   6.6  2.6   5.6  0.468  0.5
# 6   207           Kenny Wooten  RGV  14  17.0   4.2  1.7   3.4  0.511  0.1
# 7   208  Justin Wright-Foreman  ERI  15  23.8  12.8  4.8   9.5  0.503  2.2
# 8   209            James Young  WES  14  23.2  11.6  3.6  10.4  0.352  2.0
# 9   210         Omer Yurtseven  OKL  14  21.1  15.2  6.2   9.9  0.626  0.6
#
#     ...  FTA    FT%  ORB  DRB  RPG  APG  SPG  BPG  TOV   PF
# ...

# %%
df_list = []
url = 'https://basketball.realgm.com/dleague/stats/2021/Misc_Stats/Qualified/player/All/asc/%d/Regular_Season'
for i in range(1, 4):
    url_head = url %i
    df_list.append(pd.read_html(url_head)[0])
#     print(url_head)

misc = pd.concat(df_list).drop(columns = ['Dbl Dbl', 'Tpl Dbl', '40 Pts', '20 Reb', '20 Ast', 
                                         '5 Stl', '5 Blk', 'High Game', 'Techs'])
misc
# Out:
#       #                 Player Team    HOB  Ast/TO  Stl/TO  FT/FGA  W's  L's  \
# 0     1            Jalen Adams  ERI  0.236     1.4     0.4     0.1   10    4
# 1     2      Ty-Shon Alexander  CLE  0.124     1.8     0.5     0.1    5   10
# 2     3          Dakarai Allen  SLC  0.076     0.6     0.5     0.2    2    7
# 3     4             Sacar Anim  ACC  0.056     1.0     0.7     0.0    4    7
# 4     5         Brandon Ashley  IGN  0.148     0.9     0.5     0.1    8    7
# ..  ...                    ...  ...    ...     ...     ...     ...  ...  ...
# 5   206         Ryan Woolridge  OKL  0.152     2.4     0.8     0.1    8    6
# 6   207           Kenny Wooten  RGV  0.063     1.1     0.5     0.1    8    6
# 7   208  Justin Wright-Foreman  ERI  0.166     1.3     0.4     0.1   11    4
# 8   209            James Young  WES  0.144     2.8     0.7     0.1    6    8
# 9   210         Omer Yurtseven  OKL  0.177     0.8     0.2     0.2    7    7
#
#     Win %  OWS  DWS   WS
# ...

# %%
temp1 = pd.merge(averages, advanced, how = 'left', on = ['Player', 'Team'])
temp1 = temp1.drop(columns = ['#_x', '#_y'])
temp2 = pd.merge(temp1, misc, how = 'left', on = ['Player', 'Team'])
combined = temp2.drop(columns = ["#"])
combined
# Out:
#                     Player Team  GP   MPG   PPG  FGM   FGA    FG%  3PM  3PA  \
# 0              Jalen Adams  ERI  14  29.1  16.1  5.8  12.1  0.479  2.4  6.1
# 1        Ty-Shon Alexander  CLE  15  23.7   9.3  2.9   7.3  0.404  2.1  5.3
# 2            Dakarai Allen  SLC   9  20.2   5.1  1.9   4.3  0.436  0.6  1.7
# 3               Sacar Anim  ACC  11  11.1   3.3  1.5   3.5  0.410  0.4  1.6
# 4           Brandon Ashley  IGN  15  20.3  10.9  4.5   8.2  0.553  0.5  1.6
# ..                     ...  ...  ..   ...   ...  ...   ...    ...  ...  ...
# 205         Ryan Woolridge  OKL  14  20.2   6.6  2.6   5.6  0.468  0.5  1.5
# 206           Kenny Wooten  RGV  14  17.0   4.2  1.7   3.4  0.511  0.1  0.2
# 207  Justin Wright-Foreman  ERI  15  23.8  12.8  4.8   9.5  0.503  2.2  5.1
# 208            James Young  WES  14  23.2  11.6  3.6  10.4  0.352  2.0  6.1
# 209         Omer Yurtseven  OKL  14  21.1  15.2  6.2   9.9  0.626  0.6  1.5
#
# ...

# %%
combined.nunique(axis = 0)
# Out:
# Player       210
# Team          18
# GP            13
# MPG          143
# PPG          117
# FGM           69
# FGA          104
# FG%          142
# 3PM           34
# 3PA           74
# 3P%          123
# FTM           33
# FTA           40
# FT%           90
# ORB           37
# DRB           67
# RPG           80
# APG           60
# SPG           22
# BPG           23
# TOV           40
# PF            30
# TS%          151
# eFG%         151
# Total S %    184
# ORB%         100
# DRB%         126
# TRB%         112
# AST%         154
# TOV%         126
# STL%          36
# BLK%          57
# USG%         115
# PPR          103
# PPS           13
# ORtg         172
# DRtg         127
# eDiff        166
# FIC          199
# PER          127
# HOB          146
# Ast/TO        40
# Stl/TO        22
# FT/FGA         5
# W's           13
# L's           14
# Win %         51
# OWS           23
# DWS           10
# WS            25
# dtype: int64

# %%
combined.to_csv('./Data/gleague2021.csv')

# %%
df_list = []
url = 'https://basketball.realgm.com/dleague/stats/2022/Advanced_Stats/Qualified/player/All/asc/%d/Regular_Season'
for i in range(1, 5):
    url_head = url %i
    df_list.append(pd.read_html(url_head)[0])
#     print(url_head)

advanced = pd.concat(df_list)
advanced
# Out:
#       #                 Player Team    TS%   eFG%  Total S %  ORB%  DRB%  \
# 0     1           Darius Adams  FWN  0.590  0.511      166.3   2.9  12.7
# 1     2              Deng Adel  MNE  0.565  0.495      141.7   3.2  14.8
# 2     3           Santi Aldama  MHU  0.596  0.534      146.8  12.8  19.9
# 3     4           Bryce Alford  WCB  0.569  0.508      147.4   0.8  10.3
# 4     5           Jordan Allen  CLE  0.520  0.500      142.6   1.9  13.0
# ..  ...                    ...  ...    ...    ...        ...   ...   ...
# 51  352  Justin Wright-Foreman  BIR  0.611  0.588      159.3   2.3  11.8
# 52  353              Gabe York  FWN  0.536  0.490      154.9   2.5  10.3
# 53  354          Cameron Young  CLE  0.656  0.592      168.3   2.9   9.1
# 54  355              Joe Young  BIR  0.583  0.540      172.9   0.5   9.0
# 55  356      Marcus Zegarowski  LIN  0.483  0.476      122.0   1.3   9.4
#
#     TRB%  AST%  ...  STL%  BLK%  USG%  PPR  PPS   ORtg   DRtg  eDiff    FIC  \
# ...

# %%
df_list = []
url = 'https://basketball.realgm.com/dleague/stats/2022/Averages/Qualified/player/All/asc/%d/Regular_Season'
for i in range(1, 5):
    url_head = url %i
    df_list.append(pd.read_html(url_head)[0])
#     print(url_head)

averages = pd.concat(df_list)
averages
# Out:
#       #                 Player Team  GP   MPG   PPG  FGM   FGA    FG%  3PM  \
# 0     1           Darius Adams  FWN  27  28.2  17.7  5.9  13.9  0.422  2.4
# 1     2              Deng Adel  MNE  16  23.5   7.7  2.9   6.3  0.470  0.3
# 2     3           Santi Aldama  MHU  16  29.8  22.6  8.6  17.3  0.496  1.3
# 3     4           Bryce Alford  WCB  28  22.6   8.3  2.5   6.8  0.361  2.0
# 4     5           Jordan Allen  CLE  22  22.4   9.5  3.4   8.8  0.381  2.1
# ..  ...                    ...  ...  ..   ...   ...  ...   ...    ...  ...
# 51  352  Justin Wright-Foreman  BIR  14  24.7  12.3  4.6   9.7  0.471  2.3
# 52  353              Gabe York  FWN  34  37.1  21.7  7.7  19.3  0.401  3.4
# 53  354          Cameron Young  CLE  31  35.0  20.7  7.3  14.7  0.497  2.8
# 54  355              Joe Young  BIR  30  34.4  19.0  7.2  15.5  0.468  2.2
# 55  356      Marcus Zegarowski  LIN   8  27.5  10.1  3.8  10.4  0.361  2.4
#
#     ...  FTA    FT%  ORB  DRB  RPG  APG  SPG  BPG  TOV   PF
# ...

# %%
df_list = []
url = 'https://basketball.realgm.com/dleague/stats/2022/Misc_Stats/Qualified/player/All/asc/%d/Regular_Season'
for i in range(1, 5):
    url_head = url %i
    df_list.append(pd.read_html(url_head)[0])
#     print(url_head)

misc = pd.concat(df_list).drop(columns = ['Dbl Dbl', 'Tpl Dbl', '40 Pts', '20 Reb', '20 Ast', 
                                         '5 Stl', '5 Blk', 'High Game', 'Techs'])
misc
# Out:
#       #                 Player Team    HOB  Ast/TO  Stl/TO  FT/FGA  W's  L's  \
# 0     1           Darius Adams  FWN  0.251     1.3     0.7     0.2   16   11
# 1     2              Deng Adel  MNE  0.132     2.1     0.8     0.2    5   11
# 2     3           Santi Aldama  MHU  0.256     0.9     0.5     0.2   10    6
# 3     4           Bryce Alford  WCB  0.130     1.9     0.7     0.2   10   18
# 4     5           Jordan Allen  CLE  0.117     1.2     0.5     0.1   10   12
# ..  ...                    ...  ...    ...     ...     ...     ...  ...  ...
# 51  352  Justin Wright-Foreman  BIR  0.141     2.2     1.6     0.1    8    6
# 52  353              Gabe York  FWN  0.284     2.2     1.3     0.1   17   17
# 53  354          Cameron Young  CLE  0.232     1.0     0.5     0.2   10   21
# 54  355              Joe Young  BIR  0.304     3.2     0.8     0.1   18   12
# 55  356      Marcus Zegarowski  LIN  0.145     1.5     0.4     0.0    3    5
#
#     Win %  OWS  DWS   WS
# ...

# %%
url = 'https://basketball.realgm.com/dleague/transactions/callups/2022'
callups2022 = pd.read_html(url)[0]
callups2022
# Out:
#                   Player          G League Team  NBA Team  Call Up Date Pos  \
# 0    Chaundee Brown, Jr.       South Bay Lakers     Hawks   Apr 9, 2022  SF
# 1            Mac McClung       South Bay Lakers    Lakers   Apr 9, 2022  PG
# 2          Rayjon Tucker         Wisconsin Herd     Bucks   Apr 8, 2022  SF
# 3            Nate Hinton    Fort Wayne Mad Ants    Pacers   Apr 7, 2022  SF
# 4              Gabe York    Fort Wayne Mad Ants    Pacers   Apr 7, 2022  SG
# ..                   ...                    ...       ...           ...  ..
# 162      Stanley Johnson       South Bay Lakers     Bulls   Dec 9, 2021  SG
# 163           Davon Reed      Grand Rapids Gold   Nuggets   Dec 4, 2021  SF
# 164           Gary Clark  Mexico City Capitanes  Pelicans   Dec 3, 2021  SF
# 165        Javonte Smart   Sioux Falls Skyforce     Bucks  Nov 29, 2021  PG
# 166  Chaundee Brown, Jr.       South Bay Lakers    Lakers  Nov 16, 2021  SF
#
#       HT   WT  Age  YOS
# 0    6-5  215   23    0
# ...

# %%
url = 'https://basketball.realgm.com/dleague/transactions/callups/2021'
callups2021 = pd.read_html(url)[0]
callups2021
# Out:
#               Player             G League Team   NBA Team  Call Up Date Pos  \
# 0     Henry Ellenson               Raptors 905    Raptors  Mar 10, 2021  PF
# 1       Anthony Lamb  Rio Grande Valley Vipers    Rockets   Mar 8, 2021  PF
# 2         Donta Hall       NBA G League Ignite    Raptors  Feb 26, 2021  PF
# 3       Norvel Pelle          Cleveland Charge      Kings  Feb 25, 2021  PF
# 4         Tyler Cook               Iowa Wolves       Nets  Feb 24, 2021  PF
# 5     Brodric Thomas  Rio Grande Valley Vipers  Cavaliers  Feb 24, 2021  SG
# 6      Justin Patton        Westchester Knicks    Rockets  Feb 19, 2021   C
# 7     Chasson Randle        Oklahoma City Blue      Magic  Feb 15, 2021  PG
# 8   Raymond Spalding  Rio Grande Valley Vipers    Rockets  Feb 12, 2021  PF
# 9        Frank Mason       Delaware Blue Coats      Magic   Feb 3, 2021  PG
# 10      Norvel Pelle          Cleveland Charge       Nets  Jan 28, 2021  PF
# ...

# %%
temp1 = pd.merge(averages, advanced, how = 'left', on = ['Player', 'Team'])
temp1 = temp1.drop(columns = ['#_x', '#_y'])
temp2 = pd.merge(temp1, misc, how = 'left', on = ['Player', 'Team'])
combined = temp2.drop(columns = ["#"])
combined
# Out:
#                     Player Team  GP   MPG   PPG  FGM   FGA    FG%  3PM   3PA  \
# 0             Darius Adams  FWN  27  28.2  17.7  5.9  13.9  0.422  2.4   7.5
# 1                Deng Adel  MNE  16  23.5   7.7  2.9   6.3  0.470  0.3   2.1
# 2             Santi Aldama  MHU  16  29.8  22.6  8.6  17.3  0.496  1.3   4.8
# 3             Bryce Alford  WCB  28  22.6   8.3  2.5   6.8  0.361  2.0   5.4
# 4             Jordan Allen  CLE  22  22.4   9.5  3.4   8.8  0.381  2.1   5.9
# ..                     ...  ...  ..   ...   ...  ...   ...    ...  ...   ...
# 351  Justin Wright-Foreman  BIR  14  24.7  12.3  4.6   9.7  0.471  2.3   5.8
# 352              Gabe York  FWN  34  37.1  21.7  7.7  19.3  0.401  3.4  11.2
# 353          Cameron Young  CLE  31  35.0  20.7  7.3  14.7  0.497  2.8   7.0
# 354              Joe Young  BIR  30  34.4  19.0  7.2  15.5  0.468  2.2   6.1
# 355      Marcus Zegarowski  LIN   8  27.5  10.1  3.8  10.4  0.361  2.4   6.6
#
# ...

# %%
combined.nunique(axis = 0)
# Out:
# Player       355
# Team          28
# GP            35
# MPG          188
# PPG          178
# FGM           85
# FGA          150
# FG%          191
# 3PM           44
# 3PA           99
# 3P%          184
# FTM           37
# FTA           43
# FT%          179
# ORB           45
# DRB           74
# RPG           93
# APG           74
# SPG           26
# BPG           28
# TOV           41
# PF            36
# TS%          202
# eFG%         188
# Total S %    272
# ORB%         121
# DRB%         170
# TRB%         136
# AST%         192
# TOV%         162
# STL%          38
# BLK%          64
# USG%         165
# PPR          123
# PPS           12
# ORtg         228
# DRtg         153
# eDiff        245
# FIC          346
# PER          157
# HOB          208
# Ast/TO        36
# Stl/TO        23
# FT/FGA         6
# W's           24
# L's           25
# Win %        152
# OWS           37
# DWS           20
# WS            39
# dtype: int64

# %%
# Note: two different Justin Jacksons
combined[combined[['Player']].duplicated(keep=False)]
# Out:
#              Player Team  GP   MPG   PPG  FGM   FGA    FG%  3PM  3PA  ...  \
# 155  Justin Jackson  LIN   7  23.3  11.1  4.1   8.0  0.518  2.3  5.0  ...
# 156  Justin Jackson  TEX  28  36.3  22.2  7.3  17.6  0.413  3.5  9.6  ...
#
#        HOB  Ast/TO  Stl/TO  FT/FGA  W's  L's  Win %  OWS  DWS   WS
# 155  0.110     0.4     1.4     0.0    3    4  0.429  0.3  0.3  0.6
# 156  0.263     2.0     0.7     0.2   18   10  0.643  0.8  0.7  1.6
#
# [2 rows x 50 columns]

# %%
combined.to_csv('./Data/gleague2022.csv')
callups2021.to_csv('./Data/callups2021.csv')
callups2022.to_csv('./Data/callups2022.csv')

# %%
url = "https://basketball.realgm.com/dleague/players/2022"
player_bios22 = pd.read_html(url)[0]
player_bios22.to_csv('./Data/bios22.csv')

# %%
url = "https://basketball.realgm.com/dleague/players/2021"
player_bios21 = pd.read_html(url)[0]
player_bios21.to_csv('./Data/bios21.csv')

# %%
import requests
import pandas as pd
pd.set_option('display.max_columns', None)
import time
import numpy as np

# %%
test_url = "https://stats.gleague.nba.com/stats/leaguedashplayerstatscombined?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=20&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season=2021-22&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight="
r = requests.get(url = test_url).json()

# %%
col_names = r['resultSets'][0]['headers']
nba_df = pd.DataFrame(r['resultSets'][0]['rowSet'], columns = col_names)
nba_df = nba_df.rename(columns = {"PLAYER_NAME":"Player", "TEAM_ABBREVIATION":"Team"})

# %%
df = nba_df[['Player', 'Team', 'PIE']]
df.loc[:, 'PIE'] = df['PIE'].mul(100)
df
# Out:
# /Users/kenneth01px2018/DSC20/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
#              Player Team   PIE
# 0       A.J. Lawson  CPS   8.3
# 1       Aamir Simms  WES   9.3
# 2        Aaron Best  RAP   8.1
# 3       Aaron Henry  DEL   9.2
# 4     Aaron Nesmith  MNE  10.8
# ..              ...  ...   ...
# 488    Zach Hankins  BIR  13.0
# 489    Zack Rollins  LIN   2.9
# 490      Zaire Wade  SLC   2.5
# 491  Zavier Simpson  OKL  11.5
# 492  Zylan Cheatham  BIR  12.4
#
# [493 rows x 3 columns]

# %%
df.to_csv('./Data/pie_df22.csv')

# %%
url = 'https://basketball.realgm.com/dleague/stats/2023/Averages/Qualified/player/All/asc/%d/regular_Season'
df_list = []
for i in range(1, 5):
    url_head = url %i
    df_list.append(pd.read_html(url_head)[0])
#     print(url_head)

df23 = pd.concat(df_list)
df23
# Out:
#       #             Player Team  GP   MPG   PPG  FGM   FGA    FG%  3PM  3PA  \
# 0     1        Efe Abogidi  IGN   4  12.0   3.0  1.5   3.5  0.429  0.0  0.0
# 1     2       Jalen Adaway  AUS  11  21.3   5.7  2.4   5.5  0.426  0.6  2.1
# 2     3       James Akinjo  WES  10  29.3  15.6  6.0  12.7  0.472  2.0  5.7
# 3     4    Warith Alatishe  ONT  12  23.7   7.1  3.3   5.6  0.597  0.0  0.1
# 4     5  Ty-Shon Alexander  GBO  13  18.2   8.2  2.8   5.5  0.514  1.9  3.9
# ..  ...                ...  ...  ..   ...   ...  ...   ...    ...  ...  ...
# 50  351     Ryan Woolridge  OKL  12  23.3  10.3  4.3   6.7  0.638  0.3  0.5
# 51  352       Kenny Wooten  RAP   6  11.6   2.3  1.0   1.8  0.545  0.0  0.0
# 52  353          Gabe York  FWN  12  34.6  24.1  8.2  17.2  0.476  3.9  9.8
# 53  354      Cameron Young  IGN  13  20.1  12.0  3.5   8.1  0.429  0.8  2.7
# 54  355  Marcus Zegarowski  AUS  15  21.7   7.6  2.9   7.3  0.394  1.6  3.7
#
# ...

# %%
df23.to_csv('./Data/gleague2023.csv')
